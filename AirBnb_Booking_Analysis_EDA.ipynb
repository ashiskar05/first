# %% [markdown]
# <a href="https://colab.research.google.com/github/ashiskar05/first/blob/main/AirBnb_Booking_Analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name: AirBnb Booking Analysis**
#
# **Project Type - EDA**
#
# **Contribution - Individual**

# %% [markdown]
# ## **Business Context:**
#
#
# Airbnb is a popular platform for individuals to rent out their properties or book accommodations worldwide. However, both hosts and guests face challenges in optimizing their experience and maximizing their outcomes. Collection, analysis, and utilization of data plays a vital role in various aspects of Airbnb's business. It enables the company to make informed decisions, enhance user experience, optimize pricing, inventory management and drive growth. By analyzing market trends, user behavior and competitor data, Airbnb can identify growth opportunities, target new customer segments, and optimize marketing campaigns. Data-driven insights can also help Airbnb evaluate the performance of new initiatives, measure success metrics, and make data-informed decisions for future growth.​

# %% [markdown]
# ## Github Link

# %% [markdown]
# ## Table of Content
#
#
# 1.   Problem Statement
# 2.   Know your data
# 3.   Exploratory Data Analysis
# 4.   Conclusion

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Airbnb is a popular platform for individuals to rent out their properties or book accommodations worldwide. However, both hosts and guests face challenges in optimizing their experience and maximizing their outcomes. The aim of this project is to analyze Airbnb booking data to gain insights into various aspects such as demand patterns, pricing dynamics, customer satisfaction, and host characteristics. By understanding these factors, we aim to provide actionable recommendations to both hosts and guests that can enhance their booking experience, improve customer satisfaction, and optimize pricing strategies. This analysis will contribute to the overall understanding of the Airbnb ecosystem and provide valuable insights for hosts, guests, and the company itself to make informed decisions and improve the overall Airbnb booking experience.

# %% [markdown]
# ### Know your Data

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### Mount the drive and Load the data set

# %%
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv('/content/drive/My Drive/Dataset/Airbnb NYC 2019.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# top 5 records of the data set
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# Basic information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Shape of the data set
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# **There are 48895 rows and 16 columns in the dataset.**

# %%
# columns or features in the data set
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# No of duplicate records in the dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There are no duplicate records in the dataset.**

# %%
df.host_id.nunique()
# Out:
# 37457

# %% [markdown]
# **Around 37500 hosts have enrolled their properties on AirBnB.**

# %%
# No of null values per feature
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# **There are null values in the name,host_name,last_review and reviews_per_month columns.**

# %%
missing_data=round(100*(df.isnull().sum()/len(df.index)),2).reset_index()
fig = plt.figure(figsize=(18,6))
ax = sns.pointplot(x="index",y=0,data=missing_data)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values in dataset")
plt.ylabel("PERCENTAGE")
plt.xlabel("COLUMNS");

# %%
# Handling missing values
df["name"].fillna("ABC",inplace=True)
df["host_name"].fillna("ABC",inplace=True)
df["last_review"].fillna(0,inplace=True)
df["reviews_per_month"].fillna(0,inplace=True)

# %% [markdown]
# host name is replaced with string "ABC" and last_review, reviews_per_month having null values is possible and valid. So we will just fillna(0) to those null values

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# No of host per neighbourhood_group
no_of_host_per_location = df.groupby('neighbourhood_group')['host_id'].count()
no_of_host_per_location
# Out:
# neighbourhood_group
# Bronx             1091
# Brooklyn         20104
# Manhattan        21661
# Queens            5666
# Staten Island      373
# Name: host_id, dtype: int64

# %%
#Graph
plt.legend(labels = ['No. of Host'])
plt.plot(no_of_host_per_location)
plt.title('Number of host per location')
plt.ylabel('Host')
plt.xlabel('Location');

# %%
super_host = df[["host_id","host_name"]].value_counts().head(5)
ax=super_host.plot(kind='bar',color='orange')
ax.set_title(label="Super Host")
plt.show()

# %% [markdown]
# To check for super host we need to group the data by host id and host name,because host name can be same for different host id.

# %%
# Lets exclude latitude longitude as they are coordinate, id & host_id as they are unique id
df=df.drop(["id","name","host_id","latitude","longitude"],axis=1)

# %%
df.describe().round(2)
# Out:
#           price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  48895.00        48895.00           48895.00           48895.00
# mean     152.72            7.03              23.27               1.09
# std      240.15           20.51              44.55               1.60
# min        0.00            1.00               0.00               0.00
# 25%       69.00            1.00               1.00               0.04
# 50%      106.00            3.00               5.00               0.37
# 75%      175.00            5.00              24.00               1.58
# max    10000.00         1250.00             629.00              58.50
#
#        calculated_host_listings_count  availability_365
# count                        48895.00          48895.00
# mean                             7.14            112.78
# std                             32.95            131.62
# min                              1.00              0.00
# ...

# %%
df_num=df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']]

# %%
Q1 = df_num.quantile(0.25)
Q3 = df_num.quantile(0.75)
IQR = Q3 - Q1

# %%
outlier_data=round(100*((df_num < (Q1 - 1.5 * IQR)) | (df_num > (Q3 + 1.5 * IQR))).sum()/len(df_num.index),2).reset_index()

outlier_data
# Out:
#                             index      0
# 0                           price   6.08
# 1                  minimum_nights  13.51
# 2               number_of_reviews  12.31
# 3               reviews_per_month   6.77
# 4  calculated_host_listings_count  14.48
# 5                availability_365   0.00

# %% [markdown]
# #### Uni-Variate Analysis

# %%
ax=sns.countplot(x=df["neighbourhood_group"])
ax.set_title("No. Of Listings")
plt.show()

# %% [markdown]
# **Manhattan has maximum number of lodging and hospitality services followed by Brooklyn. Staten island has least number of lodging and hospitality services.**

# %%
ax=sns.countplot(x=df["room_type"])
ax.set_title("Room_Type")
plt.show();

# %% [markdown]
# **Entire home or apt is most favored room type and shared room is least favored.​**

# %%
#  find the maximum(minimum nights) spending by customer across different room type
total_room=df.groupby('room_type')['minimum_nights'].count().reset_index()
room_types=total_room.sort_values('minimum_nights',ascending=True)
room_types.head()
# Out:
#          room_type  minimum_nights
# 2      Shared room            1160
# 1     Private room           22326
# 0  Entire home/apt           25409

# %%
# create dataset
labels=list(room_types['room_type'])
sizes=list(room_types['minimum_nights'])
# create color parameter
colors=['green','orange','red']
# create explode
explode = (0.07, 0.07, 0.07)

# %%
#creating pie chart
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.title('Percentage of nights spend per room types', fontsize=20)
plt.axis("equal")
plt.show()

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)

print(cat)
print(num)
# Out:
# ['host_name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'last_review']
# ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
ax=sns.boxplot(y=df["availability_365"])
ax.set_title(label="Avaialbity of listings")
# Out:
# Text(0.5, 1.0, 'Avaialbity of listings')

# %%
ax=sns.histplot(x=df["availability_365"],kde=True,data=df)
ax.set_title(label="Avaialbity of listings");

# %%
df[df["availability_365"]==0]["availability_365"].count()
# Out:
# 17533

# %% [markdown]
# **Around 17500 properties are fully occupied.**

# %%
ax=sns.scatterplot(x=df["price"],y=df["minimum_nights"])
ax.set_title(label="Price vs Minimum nights")
# Out:
# Text(0.5, 1.0, 'Price vs Minimum nights')

# %%
sns.boxplot(y=df["price"],x=df["neighbourhood_group"],data=df)
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
#Get the host based on number of reviews
host_based_on_review_df = df.groupby(['host_name'],as_index=False)['number_of_reviews'].sum().sort_values(['number_of_reviews'],ascending = False)
host_based_on_review_df
# Out:
#       host_name  number_of_reviews
# 7136    Michael              11081
# 2377      David               8103
# 4990       John               7223
# 4635      Jason               6522
# 315        Alex               6204
# ...         ...                ...
# 6621       Manu                  0
# 6628    Manzoor                  0
# 6657   Marclynn                  0
# 6665      Maren                  0
# 11452        현선                  0
#
# [11453 rows x 2 columns]

# %%
#Get the host based on availability in a year
host_based_on_availability_df = df.groupby(['host_name'],as_index=False)['availability_365'].mean().sort_values(['availability_365'],ascending = True)
host_based_on_availability_df
# Out:
#            host_name  availability_365
# 10334           Tide               0.0
# 7361           Moira               0.0
# 11196         Yu Qun               0.0
# 8870             Rom               0.0
# 8869         Rolland               0.0
# ...              ...               ...
# 6503            Magd             365.0
# 6549      Majidudeen             365.0
# 6596         Mandela             365.0
# 6081   Lex And Derek             365.0
# 11452             현선             365.0
#
# [11453 rows x 2 columns]

# %%
#Merge two dataframe based on number of reviews and availability in a year
popular_host_df = pd.merge(host_based_on_review_df,host_based_on_availability_df,on = ['host_name']).sort_values(['availability_365','number_of_reviews'],ascending = [True,False]).rename(columns = {'number_of_reviews':'Number of reviews','availability_365':'Availability in a year'})

popular_host_df
# Out:
#              host_name  Number of reviews  Availability in a year
# 153    Gurpreet  Singh               1157                     0.0
# 532     Emily And Joel                423                     0.0
# 662     Andy & Friends                348                     0.0
# 676          En & Lora                341                     0.0
# 781             Dragan                304                     0.0
# ...                ...                ...                     ...
# 11401            Loves                  0                   365.0
# 11419            Marii                  0                   365.0
# 11420         Marilynn                  0                   365.0
# 11435       Majidudeen                  0                   365.0
# 11452               현선                  0                   365.0
#
# [11453 rows x 3 columns]

# %%
#Most popular top 5 host in new york
popular_host_df.head(5)
# Out:
#            host_name  Number of reviews  Availability in a year
# 153  Gurpreet  Singh               1157                     0.0
# 532   Emily And Joel                423                     0.0
# 662   Andy & Friends                348                     0.0
# 676        En & Lora                341                     0.0
# 781           Dragan                304                     0.0

# %%
#Create scatter plot based on number of reviews and availability in a year
popular_host_df.plot.scatter(x='Number of reviews', y='Availability in a year', xlim=(100,1000),ylim=(10,380));

# %%
plt.figure(figsize=(10,10))
sns.set_style('white')

ax = sns.boxplot(data=df, x='neighbourhood_group',y='availability_365',palette='plasma')

# Naming the Chart
ax.set_title('Relation between Neighbourhood group & Availability of rooms').set_fontsize('15')

# Naming X & Y axis
ax.set_ylabel('Availability 365 Days').set_fontsize('15')
ax.set_xlabel('Neighbourhood Group').set_fontsize('15')

#Adjusting Bar labels
ax.set_xticklabels(ax.get_xticklabels(), size = '15')
# Out:
# [Text(0, 0, 'Brooklyn'),
#  Text(1, 0, 'Manhattan'),
#  Text(2, 0, 'Queens'),
#  Text(3, 0, 'Staten Island'),
#  Text(4, 0, 'Bronx')]

# %%
#function to catogory the types of rooms.
def price_catagory(price):
  if price<50:
    return 'cheap'
  elif price>=50 and price<=200:
    return 'affordable'
  else:
    return 'Expensive'

# %%
plt.figure(figsize=(10,5))
ax= sns.countplot(x=df['price'].apply(price_catagory))
ax.set_title('Count Plot')
ax.set_xlabel('Catogories of rooms')
ax.set_ylabel("Count")
plt.show()

# %%
(df['price'].apply(price_catagory).value_counts(normalize=True)).round(2)
# Out:
# affordable    0.73
# Expensive     0.17
# cheap         0.10
# Name: price, dtype: float64

# %% [markdown]
# #### Bi-Variate Analysis

# %%
#Average price of room in different neighbourhood group
locationwiseprice_data = df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
locationwiseprice_data.plot(kind='bar',figsize=(10,6))
plt.title('Average Price of different types of room in every neighbourhood group')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,5))
ax= sns.barplot(y= 'price', x= 'room_type',data=df)
ax.set_title('Price vs Room Type')
ax.set_xlabel('Room Type')
ax.set_ylabel("Price")
plt.show()

# %% [markdown]
# **Average price of entire home/apt is highest in Manhattan.**

# %%
# reviews vs room type
review_data = df.groupby(['neighbourhood_group','room_type'])['number_of_reviews'].count().unstack()
review_data
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           652           60
# Brooklyn                        9559         10132          413
# Manhattan                      13199          7982          480
# Queens                          2096          3372          198
# Staten Island                    176           188            9

# %%
#plot graph
review_data.plot(kind='bar',figsize=(10,5))
plt.title('Number of listings room type wise')
plt.legend()
plt.show()

# %%
busiest_area = df.groupby(['neighbourhood','neighbourhood_group'])['minimum_nights'].sum().reset_index()
a=busiest_area.sort_values(by='minimum_nights', ascending=False).head(5)
a
# Out:
#           neighbourhood neighbourhood_group  minimum_nights
# 214        Williamsburg            Brooklyn           24415
# 13   Bedford-Stuyvesant            Brooklyn           21130
# 202     Upper West Side           Manhattan           18759
# 127             Midtown           Manhattan           17792
# 94               Harlem           Manhattan           17050

# %%
plt.figure(figsize=(12,8))
ax=sns.barplot(y="minimum_nights",x="neighbourhood",data=a)
ax.set_title(label="Busiest area")
plt.show()

# %%
sns.scatterplot(x="price",y="number_of_reviews",data=df);

# %%
df["price"].quantile(.75)
# Out:
# 175.0

# %% [markdown]
# **Price is inversely proportional to number of bookings. Properties within $200 are most likely to be booked.**

# %%
df[["price"]].describe()
# Out:
#               price
# count  48895.000000
# mean     152.720687
# std      240.154170
# min        0.000000
# 25%       69.000000
# 50%      106.000000
# 75%      175.000000
# max    10000.000000

# %% [markdown]
# #### Multi-Variate Analysis

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap='rainbow',mask=np.triu(df.corr(),+1))
plt.title("Heat Map")
plt.show();
# Out:
# <ipython-input-51-3d23a367fd11>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap='rainbow',mask=np.triu(df.corr(),+1))
